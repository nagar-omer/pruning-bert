# %% [markdown]
# ## Bert Pruning over GLUE benchmark (MRPC)
#
# ### Input
# To activate, fill in the "hyper_params.json" file (or create one of yuor own if you wish)<br>
# you can specify the following parameters:
#   * task_name
#   * data_dir
#   * output_dir
#   * total_training_steps: <br>total number of trainig steps
#   * fine_tune_steps: <br>number of training steps with 0 sparsity
#   * epoch_per_training_step: <br>number of training epochs for each training step
#   * pruning_init_sparse: <br>starting sparsity ratio 0-100,
#   * pruning_final_sparse: <br>target sparsity ratio 0-100,
#   * learning_rate
#   * weight_decay
#   * adam_epsilon
#   * max_grad_norm
#
# ### Output
#  When the training is complete a new directory will be created: models/\<model-creation-time\> <br>
#  it will contain:<br>
#   * ONNX<br>a directory with onnx file for each trainig step
#   * pt_model_dict<br>a directory with pytorch state-dict pt file for each trainig step
#   * results-file<br> csv file with acuuracy measures for each training step
#   * sparsity-graph<br> a graph of sparsity as function of trainig step

# %% [markdown]
# ### Imports

# %%
from run_basic_finetune import *

# %% [markdown]
# ### Train

# %%
PATH_TO_HYPER_PARAMS = "hyper_params.json"
run(hyper_params=PATH_TO_HYPER_PARAMS)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=10.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Evaluation', max=51.0, style=ProgressStyle(description_wi…
# 0 ================================================== sparsity 0
# bert.embeddings.word_embeddings.weight             0.0
# bert.embeddings.position_embeddings.weight         0.0
# bert.embeddings.token_type_embeddings.weight       0.0
# bert.embeddings.LayerNorm.weight                   0.0
# bert.embeddings.LayerNorm.bias                     0.0
# bert.encoder.layer.0.attention.self.query.weight   0.0
# bert.encoder.layer.0.attention.self.query.bias     0.0
# bert.encoder.layer.0.attention.self.key.weight     0.0
# bert.encoder.layer.0.attention.self.key.bias       0.0
# bert.encoder.layer.0.attention.self.value.weight   0.0
# bert.encoder.layer.0.attention.self.value.bias     0.0
# bert.encoder.layer.0.attention.output.dense.weight 0.0
# bert.encoder.layer.0.attention.output.dense.bias   0.0
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.0.intermediate.dense.weight     0.0
# bert.encoder.layer.0.intermediate.dense.bias       0.0
# bert.encoder.layer.0.output.dense.weight           0.0
# bert.encoder.layer.0.output.dense.bias             0.0
# bert.encoder.layer.0.output.LayerNorm.weight       0.0
# bert.encoder.layer.0.output.LayerNorm.bias         0.0
# bert.encoder.layer.1.attention.self.query.weight   0.0
# bert.encoder.layer.1.attention.self.query.bias     0.0
# bert.encoder.layer.1.attention.self.key.weight     0.0
# bert.encoder.layer.1.attention.self.key.bias       0.0
# bert.encoder.layer.1.attention.self.value.weight   0.0
# bert.encoder.layer.1.attention.self.value.bias     0.0
# bert.encoder.layer.1.attention.output.dense.weight 0.0
# bert.encoder.layer.1.attention.output.dense.bias   0.0
# bert.encoder.layer.1.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.1.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.1.intermediate.dense.weight     0.0
# bert.encoder.layer.1.intermediate.dense.bias       0.0
# bert.encoder.layer.1.output.dense.weight           0.0
# bert.encoder.layer.1.output.dense.bias             0.0
# bert.encoder.layer.1.output.LayerNorm.weight       0.0
# bert.encoder.layer.1.output.LayerNorm.bias         0.0
# bert.encoder.layer.2.attention.self.query.weight   0.0
# bert.encoder.layer.2.attention.self.query.bias     0.0
# bert.encoder.layer.2.attention.self.key.weight     0.0
# bert.encoder.layer.2.attention.self.key.bias       0.0
# bert.encoder.layer.2.attention.self.value.weight   0.0
# bert.encoder.layer.2.attention.self.value.bias     0.0
# bert.encoder.layer.2.attention.output.dense.weight 0.0
# bert.encoder.layer.2.attention.output.dense.bias   0.0
# bert.encoder.layer.2.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.2.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.2.intermediate.dense.weight     0.0
# bert.encoder.layer.2.intermediate.dense.bias       0.0
# bert.encoder.layer.2.output.dense.weight           0.0
# bert.encoder.layer.2.output.dense.bias             0.0
# bert.encoder.layer.2.output.LayerNorm.weight       0.0
# bert.encoder.layer.2.output.LayerNorm.bias         0.0
# bert.encoder.layer.3.attention.self.query.weight   0.0
# bert.encoder.layer.3.attention.self.query.bias     0.0
# bert.encoder.layer.3.attention.self.key.weight     0.0
# bert.encoder.layer.3.attention.self.key.bias       0.0
# bert.encoder.layer.3.attention.self.value.weight   0.0
# bert.encoder.layer.3.attention.self.value.bias     0.0
# bert.encoder.layer.3.attention.output.dense.weight 0.0
# bert.encoder.layer.3.attention.output.dense.bias   0.0
# bert.encoder.layer.3.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.3.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.3.intermediate.dense.weight     0.0
# bert.encoder.layer.3.intermediate.dense.bias       0.0
# bert.encoder.layer.3.output.dense.weight           0.0
# bert.encoder.layer.3.output.dense.bias             0.0
# bert.encoder.layer.3.output.LayerNorm.weight       0.0
# bert.encoder.layer.3.output.LayerNorm.bias         0.0
# bert.encoder.layer.4.attention.self.query.weight   0.0
# bert.encoder.layer.4.attention.self.query.bias     0.0
# bert.encoder.layer.4.attention.self.key.weight     0.0
# bert.encoder.layer.4.attention.self.key.bias       0.0
# bert.encoder.layer.4.attention.self.value.weight   0.0
# bert.encoder.layer.4.attention.self.value.bias     0.0
# bert.encoder.layer.4.attention.output.dense.weight 0.0
# bert.encoder.layer.4.attention.output.dense.bias   0.0
# bert.encoder.layer.4.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.4.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.4.intermediate.dense.weight     0.0
# bert.encoder.layer.4.intermediate.dense.bias       0.0
# bert.encoder.layer.4.output.dense.weight           0.0
# bert.encoder.layer.4.output.dense.bias             0.0
# bert.encoder.layer.4.output.LayerNorm.weight       0.0
# bert.encoder.layer.4.output.LayerNorm.bias         0.0
# bert.encoder.layer.5.attention.self.query.weight   0.0
# bert.encoder.layer.5.attention.self.query.bias     0.0
# bert.encoder.layer.5.attention.self.key.weight     0.0
# bert.encoder.layer.5.attention.self.key.bias       0.0
# bert.encoder.layer.5.attention.self.value.weight   0.0
# bert.encoder.layer.5.attention.self.value.bias     0.0
# bert.encoder.layer.5.attention.output.dense.weight 0.0
# bert.encoder.layer.5.attention.output.dense.bias   0.0
# bert.encoder.layer.5.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.5.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.5.intermediate.dense.weight     0.0
# bert.encoder.layer.5.intermediate.dense.bias       0.0
# bert.encoder.layer.5.output.dense.weight           0.0
# bert.encoder.layer.5.output.dense.bias             0.0
# bert.encoder.layer.5.output.LayerNorm.weight       0.0
# bert.encoder.layer.5.output.LayerNorm.bias         0.0
# bert.encoder.layer.6.attention.self.query.weight   0.0
# bert.encoder.layer.6.attention.self.query.bias     0.0
# bert.encoder.layer.6.attention.self.key.weight     0.0
# bert.encoder.layer.6.attention.self.key.bias       0.0
# bert.encoder.layer.6.attention.self.value.weight   0.0
# bert.encoder.layer.6.attention.self.value.bias     0.0
# bert.encoder.layer.6.attention.output.dense.weight 0.0
# bert.encoder.layer.6.attention.output.dense.bias   0.0
# bert.encoder.layer.6.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.6.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.6.intermediate.dense.weight     0.0
# bert.encoder.layer.6.intermediate.dense.bias       0.0
# bert.encoder.layer.6.output.dense.weight           0.0
# bert.encoder.layer.6.output.dense.bias             0.0
# bert.encoder.layer.6.output.LayerNorm.weight       0.0
# bert.encoder.layer.6.output.LayerNorm.bias         0.0
# bert.encoder.layer.7.attention.self.query.weight   0.0
# bert.encoder.layer.7.attention.self.query.bias     0.0
# bert.encoder.layer.7.attention.self.key.weight     0.0
# bert.encoder.layer.7.attention.self.key.bias       0.0
# bert.encoder.layer.7.attention.self.value.weight   0.0
# bert.encoder.layer.7.attention.self.value.bias     0.0
# bert.encoder.layer.7.attention.output.dense.weight 0.0
# bert.encoder.layer.7.attention.output.dense.bias   0.0
# bert.encoder.layer.7.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.7.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.7.intermediate.dense.weight     0.0
# bert.encoder.layer.7.intermediate.dense.bias       0.0
# bert.encoder.layer.7.output.dense.weight           0.0
# bert.encoder.layer.7.output.dense.bias             0.0
# bert.encoder.layer.7.output.LayerNorm.weight       0.0
# bert.encoder.layer.7.output.LayerNorm.bias         0.0
# bert.encoder.layer.8.attention.self.query.weight   0.0
# bert.encoder.layer.8.attention.self.query.bias     0.0
# bert.encoder.layer.8.attention.self.key.weight     0.0
# bert.encoder.layer.8.attention.self.key.bias       0.0
# bert.encoder.layer.8.attention.self.value.weight   0.0
# bert.encoder.layer.8.attention.self.value.bias     0.0
# bert.encoder.layer.8.attention.output.dense.weight 0.0
# bert.encoder.layer.8.attention.output.dense.bias   0.0
# bert.encoder.layer.8.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.8.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.8.intermediate.dense.weight     0.0
# bert.encoder.layer.8.intermediate.dense.bias       0.0
# bert.encoder.layer.8.output.dense.weight           0.0
# bert.encoder.layer.8.output.dense.bias             0.0
# bert.encoder.layer.8.output.LayerNorm.weight       0.0
# bert.encoder.layer.8.output.LayerNorm.bias         0.0
# bert.encoder.layer.9.attention.self.query.weight   0.0
# bert.encoder.layer.9.attention.self.query.bias     0.0
# bert.encoder.layer.9.attention.self.key.weight     0.0
# bert.encoder.layer.9.attention.self.key.bias       0.0
# bert.encoder.layer.9.attention.self.value.weight   0.0
# bert.encoder.layer.9.attention.self.value.bias     0.0
# bert.encoder.layer.9.attention.output.dense.weight 0.0
# bert.encoder.layer.9.attention.output.dense.bias   0.0
# bert.encoder.layer.9.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.9.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.9.intermediate.dense.weight     0.0
# bert.encoder.layer.9.intermediate.dense.bias       0.0
# bert.encoder.layer.9.output.dense.weight           0.0
# bert.encoder.layer.9.output.dense.bias             0.0
# bert.encoder.layer.9.output.LayerNorm.weight       0.0
# bert.encoder.layer.9.output.LayerNorm.bias         0.0
# bert.encoder.layer.10.attention.self.query.weight  0.0
# bert.encoder.layer.10.attention.self.query.bias    0.0
# bert.encoder.layer.10.attention.self.key.weight    0.0
# bert.encoder.layer.10.attention.self.key.bias      0.0
# bert.encoder.layer.10.attention.self.value.weight  0.0
# bert.encoder.layer.10.attention.self.value.bias    0.0
# bert.encoder.layer.10.attention.output.dense.weight 0.0
# bert.encoder.layer.10.attention.output.dense.bias  0.0
# bert.encoder.layer.10.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.10.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.10.intermediate.dense.weight    0.0
# bert.encoder.layer.10.intermediate.dense.bias      0.0
# bert.encoder.layer.10.output.dense.weight          0.0
# bert.encoder.layer.10.output.dense.bias            0.0
# bert.encoder.layer.10.output.LayerNorm.weight      0.0
# bert.encoder.layer.10.output.LayerNorm.bias        0.0
# bert.encoder.layer.11.attention.self.query.weight  0.0
# bert.encoder.layer.11.attention.self.query.bias    0.0
# bert.encoder.layer.11.attention.self.key.weight    0.0
# bert.encoder.layer.11.attention.self.key.bias      0.0
# bert.encoder.layer.11.attention.self.value.weight  0.0
# bert.encoder.layer.11.attention.self.value.bias    0.0
# bert.encoder.layer.11.attention.output.dense.weight 0.0
# bert.encoder.layer.11.attention.output.dense.bias  0.0
# bert.encoder.layer.11.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.11.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.11.intermediate.dense.weight    0.0
# bert.encoder.layer.11.intermediate.dense.bias      0.0
# bert.encoder.layer.11.output.dense.weight          0.0
# bert.encoder.layer.11.output.dense.bias            0.0
# bert.encoder.layer.11.output.LayerNorm.weight      0.0
# bert.encoder.layer.11.output.LayerNorm.bias        0.0
# bert.pooler.dense.weight                           0.0
# bert.pooler.dense.bias                             0.0
# classifier.weight                                  0.0
# classifier.bias                                    0.0
# ==================================================
# eval_loss                      0.9298344574430409
# eval_acc                       0.8553921568627451
# eval_f1                        0.8981001727115717
# eval_acc_and_f1                0.8767461647871584
# epoch                          10.0
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=10.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Evaluation', max=51.0, style=ProgressStyle(description_wi…
# 1 ================================================== sparsity 0
# bert.embeddings.word_embeddings.weight             0.0
# bert.embeddings.position_embeddings.weight         0.0
# bert.embeddings.token_type_embeddings.weight       0.0
# bert.embeddings.LayerNorm.weight                   0.0
# bert.embeddings.LayerNorm.bias                     0.0
# bert.encoder.layer.0.attention.self.query.weight   0.0
# bert.encoder.layer.0.attention.self.query.bias     0.0
# bert.encoder.layer.0.attention.self.key.weight     0.0
# bert.encoder.layer.0.attention.self.key.bias       0.0
# bert.encoder.layer.0.attention.self.value.weight   0.0
# bert.encoder.layer.0.attention.self.value.bias     0.0
# bert.encoder.layer.0.attention.output.dense.weight 0.0
# bert.encoder.layer.0.attention.output.dense.bias   0.0
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.0.intermediate.dense.weight     0.0
# bert.encoder.layer.0.intermediate.dense.bias       0.0
# bert.encoder.layer.0.output.dense.weight           0.0
# bert.encoder.layer.0.output.dense.bias             0.0
# bert.encoder.layer.0.output.LayerNorm.weight       0.0
# bert.encoder.layer.0.output.LayerNorm.bias         0.0
# bert.encoder.layer.1.attention.self.query.weight   0.0
# bert.encoder.layer.1.attention.self.query.bias     0.0
# bert.encoder.layer.1.attention.self.key.weight     0.0
# bert.encoder.layer.1.attention.self.key.bias       0.0
# bert.encoder.layer.1.attention.self.value.weight   0.0
# bert.encoder.layer.1.attention.self.value.bias     0.0
# bert.encoder.layer.1.attention.output.dense.weight 0.0
# bert.encoder.layer.1.attention.output.dense.bias   0.0
# bert.encoder.layer.1.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.1.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.1.intermediate.dense.weight     0.0
# bert.encoder.layer.1.intermediate.dense.bias       0.0
# bert.encoder.layer.1.output.dense.weight           0.0
# bert.encoder.layer.1.output.dense.bias             0.0
# bert.encoder.layer.1.output.LayerNorm.weight       0.0
# bert.encoder.layer.1.output.LayerNorm.bias         0.0
# bert.encoder.layer.2.attention.self.query.weight   0.0
# bert.encoder.layer.2.attention.self.query.bias     0.0
# bert.encoder.layer.2.attention.self.key.weight     0.0
# bert.encoder.layer.2.attention.self.key.bias       0.0
# bert.encoder.layer.2.attention.self.value.weight   0.0
# bert.encoder.layer.2.attention.self.value.bias     0.0
# bert.encoder.layer.2.attention.output.dense.weight 0.0
# bert.encoder.layer.2.attention.output.dense.bias   0.0
# bert.encoder.layer.2.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.2.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.2.intermediate.dense.weight     0.0
# bert.encoder.layer.2.intermediate.dense.bias       0.0
# bert.encoder.layer.2.output.dense.weight           0.0
# bert.encoder.layer.2.output.dense.bias             0.0
# bert.encoder.layer.2.output.LayerNorm.weight       0.0
# bert.encoder.layer.2.output.LayerNorm.bias         0.0
# bert.encoder.layer.3.attention.self.query.weight   0.0
# bert.encoder.layer.3.attention.self.query.bias     0.0
# bert.encoder.layer.3.attention.self.key.weight     0.0
# bert.encoder.layer.3.attention.self.key.bias       0.0
# bert.encoder.layer.3.attention.self.value.weight   0.0
# bert.encoder.layer.3.attention.self.value.bias     0.0
# bert.encoder.layer.3.attention.output.dense.weight 0.0
# bert.encoder.layer.3.attention.output.dense.bias   0.0
# bert.encoder.layer.3.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.3.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.3.intermediate.dense.weight     0.0
# bert.encoder.layer.3.intermediate.dense.bias       0.0
# bert.encoder.layer.3.output.dense.weight           0.0
# bert.encoder.layer.3.output.dense.bias             0.0
# bert.encoder.layer.3.output.LayerNorm.weight       0.0
# bert.encoder.layer.3.output.LayerNorm.bias         0.0
# bert.encoder.layer.4.attention.self.query.weight   0.0
# bert.encoder.layer.4.attention.self.query.bias     0.0
# bert.encoder.layer.4.attention.self.key.weight     0.0
# bert.encoder.layer.4.attention.self.key.bias       0.0
# bert.encoder.layer.4.attention.self.value.weight   0.0
# bert.encoder.layer.4.attention.self.value.bias     0.0
# bert.encoder.layer.4.attention.output.dense.weight 0.0
# bert.encoder.layer.4.attention.output.dense.bias   0.0
# bert.encoder.layer.4.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.4.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.4.intermediate.dense.weight     0.0
# bert.encoder.layer.4.intermediate.dense.bias       0.0
# bert.encoder.layer.4.output.dense.weight           0.0
# bert.encoder.layer.4.output.dense.bias             0.0
# bert.encoder.layer.4.output.LayerNorm.weight       0.0
# bert.encoder.layer.4.output.LayerNorm.bias         0.0
# bert.encoder.layer.5.attention.self.query.weight   0.0
# bert.encoder.layer.5.attention.self.query.bias     0.0
# bert.encoder.layer.5.attention.self.key.weight     0.0
# bert.encoder.layer.5.attention.self.key.bias       0.0
# bert.encoder.layer.5.attention.self.value.weight   0.0
# bert.encoder.layer.5.attention.self.value.bias     0.0
# bert.encoder.layer.5.attention.output.dense.weight 0.0
# bert.encoder.layer.5.attention.output.dense.bias   0.0
# bert.encoder.layer.5.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.5.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.5.intermediate.dense.weight     0.0
# bert.encoder.layer.5.intermediate.dense.bias       0.0
# bert.encoder.layer.5.output.dense.weight           0.0
# bert.encoder.layer.5.output.dense.bias             0.0
# bert.encoder.layer.5.output.LayerNorm.weight       0.0
# bert.encoder.layer.5.output.LayerNorm.bias         0.0
# bert.encoder.layer.6.attention.self.query.weight   0.0
# bert.encoder.layer.6.attention.self.query.bias     0.0
# bert.encoder.layer.6.attention.self.key.weight     0.0
# bert.encoder.layer.6.attention.self.key.bias       0.0
# bert.encoder.layer.6.attention.self.value.weight   0.0
# bert.encoder.layer.6.attention.self.value.bias     0.0
# bert.encoder.layer.6.attention.output.dense.weight 0.0
# bert.encoder.layer.6.attention.output.dense.bias   0.0
# bert.encoder.layer.6.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.6.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.6.intermediate.dense.weight     0.0
# bert.encoder.layer.6.intermediate.dense.bias       0.0
# bert.encoder.layer.6.output.dense.weight           0.0
# bert.encoder.layer.6.output.dense.bias             0.0
# bert.encoder.layer.6.output.LayerNorm.weight       0.0
# bert.encoder.layer.6.output.LayerNorm.bias         0.0
# bert.encoder.layer.7.attention.self.query.weight   0.0
# bert.encoder.layer.7.attention.self.query.bias     0.0
# bert.encoder.layer.7.attention.self.key.weight     0.0
# bert.encoder.layer.7.attention.self.key.bias       0.0
# bert.encoder.layer.7.attention.self.value.weight   0.0
# bert.encoder.layer.7.attention.self.value.bias     0.0
# bert.encoder.layer.7.attention.output.dense.weight 0.0
# bert.encoder.layer.7.attention.output.dense.bias   0.0
# bert.encoder.layer.7.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.7.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.7.intermediate.dense.weight     0.0
# bert.encoder.layer.7.intermediate.dense.bias       0.0
# bert.encoder.layer.7.output.dense.weight           0.0
# bert.encoder.layer.7.output.dense.bias             0.0
# bert.encoder.layer.7.output.LayerNorm.weight       0.0
# bert.encoder.layer.7.output.LayerNorm.bias         0.0
# bert.encoder.layer.8.attention.self.query.weight   0.0
# bert.encoder.layer.8.attention.self.query.bias     0.0
# bert.encoder.layer.8.attention.self.key.weight     0.0
# bert.encoder.layer.8.attention.self.key.bias       0.0
# bert.encoder.layer.8.attention.self.value.weight   0.0
# bert.encoder.layer.8.attention.self.value.bias     0.0
# bert.encoder.layer.8.attention.output.dense.weight 0.0
# bert.encoder.layer.8.attention.output.dense.bias   0.0
# bert.encoder.layer.8.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.8.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.8.intermediate.dense.weight     0.0
# bert.encoder.layer.8.intermediate.dense.bias       0.0
# bert.encoder.layer.8.output.dense.weight           0.0
# bert.encoder.layer.8.output.dense.bias             0.0
# bert.encoder.layer.8.output.LayerNorm.weight       0.0
# bert.encoder.layer.8.output.LayerNorm.bias         0.0
# bert.encoder.layer.9.attention.self.query.weight   0.0
# bert.encoder.layer.9.attention.self.query.bias     0.0
# bert.encoder.layer.9.attention.self.key.weight     0.0
# bert.encoder.layer.9.attention.self.key.bias       0.0
# bert.encoder.layer.9.attention.self.value.weight   0.0
# bert.encoder.layer.9.attention.self.value.bias     0.0
# bert.encoder.layer.9.attention.output.dense.weight 0.0
# bert.encoder.layer.9.attention.output.dense.bias   0.0
# bert.encoder.layer.9.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.9.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.9.intermediate.dense.weight     0.0
# bert.encoder.layer.9.intermediate.dense.bias       0.0
# bert.encoder.layer.9.output.dense.weight           0.0
# bert.encoder.layer.9.output.dense.bias             0.0
# bert.encoder.layer.9.output.LayerNorm.weight       0.0
# bert.encoder.layer.9.output.LayerNorm.bias         0.0
# bert.encoder.layer.10.attention.self.query.weight  0.0
# bert.encoder.layer.10.attention.self.query.bias    0.0
# bert.encoder.layer.10.attention.self.key.weight    0.0
# bert.encoder.layer.10.attention.self.key.bias      0.0
# bert.encoder.layer.10.attention.self.value.weight  0.0
# bert.encoder.layer.10.attention.self.value.bias    0.0
# bert.encoder.layer.10.attention.output.dense.weight 0.0
# bert.encoder.layer.10.attention.output.dense.bias  0.0
# bert.encoder.layer.10.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.10.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.10.intermediate.dense.weight    0.0
# bert.encoder.layer.10.intermediate.dense.bias      0.0
# bert.encoder.layer.10.output.dense.weight          0.0
# bert.encoder.layer.10.output.dense.bias            0.0
# bert.encoder.layer.10.output.LayerNorm.weight      0.0
# bert.encoder.layer.10.output.LayerNorm.bias        0.0
# bert.encoder.layer.11.attention.self.query.weight  0.0
# bert.encoder.layer.11.attention.self.query.bias    0.0
# bert.encoder.layer.11.attention.self.key.weight    0.0
# bert.encoder.layer.11.attention.self.key.bias      0.0
# bert.encoder.layer.11.attention.self.value.weight  0.0
# bert.encoder.layer.11.attention.self.value.bias    0.0
# bert.encoder.layer.11.attention.output.dense.weight 0.0
# bert.encoder.layer.11.attention.output.dense.bias  0.0
# bert.encoder.layer.11.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.11.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.11.intermediate.dense.weight    0.0
# bert.encoder.layer.11.intermediate.dense.bias      0.0
# bert.encoder.layer.11.output.dense.weight          0.0
# bert.encoder.layer.11.output.dense.bias            0.0
# bert.encoder.layer.11.output.LayerNorm.weight      0.0
# bert.encoder.layer.11.output.LayerNorm.bias        0.0
# bert.pooler.dense.weight                           0.0
# bert.pooler.dense.bias                             0.0
# classifier.weight                                  0.0
# classifier.bias                                    0.0
# ==================================================
# eval_loss                      1.1895641396735228
# eval_acc                       0.8504901960784313
# eval_f1                        0.893542757417103
# eval_acc_and_f1                0.8720164767477672
# epoch                          10.0
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=10.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Evaluation', max=51.0, style=ProgressStyle(description_wi…
# 2 ================================================== sparsity 0
# bert.embeddings.word_embeddings.weight             0.0
# bert.embeddings.position_embeddings.weight         0.0
# bert.embeddings.token_type_embeddings.weight       0.0
# bert.embeddings.LayerNorm.weight                   0.0
# bert.embeddings.LayerNorm.bias                     0.0
# bert.encoder.layer.0.attention.self.query.weight   0.0
# bert.encoder.layer.0.attention.self.query.bias     0.0
# bert.encoder.layer.0.attention.self.key.weight     0.0
# bert.encoder.layer.0.attention.self.key.bias       0.0
# bert.encoder.layer.0.attention.self.value.weight   0.0
# bert.encoder.layer.0.attention.self.value.bias     0.0
# bert.encoder.layer.0.attention.output.dense.weight 0.0
# bert.encoder.layer.0.attention.output.dense.bias   0.0
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.0.intermediate.dense.weight     0.0
# bert.encoder.layer.0.intermediate.dense.bias       0.0
# bert.encoder.layer.0.output.dense.weight           0.0
# bert.encoder.layer.0.output.dense.bias             0.0
# bert.encoder.layer.0.output.LayerNorm.weight       0.0
# bert.encoder.layer.0.output.LayerNorm.bias         0.0
# bert.encoder.layer.1.attention.self.query.weight   0.0
# bert.encoder.layer.1.attention.self.query.bias     0.0
# bert.encoder.layer.1.attention.self.key.weight     0.0
# bert.encoder.layer.1.attention.self.key.bias       0.0
# bert.encoder.layer.1.attention.self.value.weight   0.0
# bert.encoder.layer.1.attention.self.value.bias     0.0
# bert.encoder.layer.1.attention.output.dense.weight 0.0
# bert.encoder.layer.1.attention.output.dense.bias   0.0
# bert.encoder.layer.1.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.1.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.1.intermediate.dense.weight     0.0
# bert.encoder.layer.1.intermediate.dense.bias       0.0
# bert.encoder.layer.1.output.dense.weight           0.0
# bert.encoder.layer.1.output.dense.bias             0.0
# bert.encoder.layer.1.output.LayerNorm.weight       0.0
# bert.encoder.layer.1.output.LayerNorm.bias         0.0
# bert.encoder.layer.2.attention.self.query.weight   0.0
# bert.encoder.layer.2.attention.self.query.bias     0.0
# bert.encoder.layer.2.attention.self.key.weight     0.0
# bert.encoder.layer.2.attention.self.key.bias       0.0
# bert.encoder.layer.2.attention.self.value.weight   0.0
# bert.encoder.layer.2.attention.self.value.bias     0.0
# bert.encoder.layer.2.attention.output.dense.weight 0.0
# bert.encoder.layer.2.attention.output.dense.bias   0.0
# bert.encoder.layer.2.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.2.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.2.intermediate.dense.weight     0.0
# bert.encoder.layer.2.intermediate.dense.bias       0.0
# bert.encoder.layer.2.output.dense.weight           0.0
# bert.encoder.layer.2.output.dense.bias             0.0
# bert.encoder.layer.2.output.LayerNorm.weight       0.0
# bert.encoder.layer.2.output.LayerNorm.bias         0.0
# bert.encoder.layer.3.attention.self.query.weight   0.0
# bert.encoder.layer.3.attention.self.query.bias     0.0
# bert.encoder.layer.3.attention.self.key.weight     0.0
# bert.encoder.layer.3.attention.self.key.bias       0.0
# bert.encoder.layer.3.attention.self.value.weight   0.0
# bert.encoder.layer.3.attention.self.value.bias     0.0
# bert.encoder.layer.3.attention.output.dense.weight 0.0
# bert.encoder.layer.3.attention.output.dense.bias   0.0
# bert.encoder.layer.3.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.3.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.3.intermediate.dense.weight     0.0
# bert.encoder.layer.3.intermediate.dense.bias       0.0
# bert.encoder.layer.3.output.dense.weight           0.0
# bert.encoder.layer.3.output.dense.bias             0.0
# bert.encoder.layer.3.output.LayerNorm.weight       0.0
# bert.encoder.layer.3.output.LayerNorm.bias         0.0
# bert.encoder.layer.4.attention.self.query.weight   0.0
# bert.encoder.layer.4.attention.self.query.bias     0.0
# bert.encoder.layer.4.attention.self.key.weight     0.0
# bert.encoder.layer.4.attention.self.key.bias       0.0
# bert.encoder.layer.4.attention.self.value.weight   0.0
# bert.encoder.layer.4.attention.self.value.bias     0.0
# bert.encoder.layer.4.attention.output.dense.weight 0.0
# bert.encoder.layer.4.attention.output.dense.bias   0.0
# bert.encoder.layer.4.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.4.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.4.intermediate.dense.weight     0.0
# bert.encoder.layer.4.intermediate.dense.bias       0.0
# bert.encoder.layer.4.output.dense.weight           0.0
# bert.encoder.layer.4.output.dense.bias             0.0
# bert.encoder.layer.4.output.LayerNorm.weight       0.0
# bert.encoder.layer.4.output.LayerNorm.bias         0.0
# bert.encoder.layer.5.attention.self.query.weight   0.0
# bert.encoder.layer.5.attention.self.query.bias     0.0
# bert.encoder.layer.5.attention.self.key.weight     0.0
# bert.encoder.layer.5.attention.self.key.bias       0.0
# bert.encoder.layer.5.attention.self.value.weight   0.0
# bert.encoder.layer.5.attention.self.value.bias     0.0
# bert.encoder.layer.5.attention.output.dense.weight 0.0
# bert.encoder.layer.5.attention.output.dense.bias   0.0
# bert.encoder.layer.5.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.5.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.5.intermediate.dense.weight     0.0
# bert.encoder.layer.5.intermediate.dense.bias       0.0
# bert.encoder.layer.5.output.dense.weight           0.0
# bert.encoder.layer.5.output.dense.bias             0.0
# bert.encoder.layer.5.output.LayerNorm.weight       0.0
# bert.encoder.layer.5.output.LayerNorm.bias         0.0
# bert.encoder.layer.6.attention.self.query.weight   0.0
# bert.encoder.layer.6.attention.self.query.bias     0.0
# bert.encoder.layer.6.attention.self.key.weight     0.0
# bert.encoder.layer.6.attention.self.key.bias       0.0
# bert.encoder.layer.6.attention.self.value.weight   0.0
# bert.encoder.layer.6.attention.self.value.bias     0.0
# bert.encoder.layer.6.attention.output.dense.weight 0.0
# bert.encoder.layer.6.attention.output.dense.bias   0.0
# bert.encoder.layer.6.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.6.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.6.intermediate.dense.weight     0.0
# bert.encoder.layer.6.intermediate.dense.bias       0.0
# bert.encoder.layer.6.output.dense.weight           0.0
# bert.encoder.layer.6.output.dense.bias             0.0
# bert.encoder.layer.6.output.LayerNorm.weight       0.0
# bert.encoder.layer.6.output.LayerNorm.bias         0.0
# bert.encoder.layer.7.attention.self.query.weight   0.0
# bert.encoder.layer.7.attention.self.query.bias     0.0
# bert.encoder.layer.7.attention.self.key.weight     0.0
# bert.encoder.layer.7.attention.self.key.bias       0.0
# bert.encoder.layer.7.attention.self.value.weight   0.0
# bert.encoder.layer.7.attention.self.value.bias     0.0
# bert.encoder.layer.7.attention.output.dense.weight 0.0
# bert.encoder.layer.7.attention.output.dense.bias   0.0
# bert.encoder.layer.7.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.7.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.7.intermediate.dense.weight     0.0
# bert.encoder.layer.7.intermediate.dense.bias       0.0
# bert.encoder.layer.7.output.dense.weight           0.0
# bert.encoder.layer.7.output.dense.bias             0.0
# bert.encoder.layer.7.output.LayerNorm.weight       0.0
# bert.encoder.layer.7.output.LayerNorm.bias         0.0
# bert.encoder.layer.8.attention.self.query.weight   0.0
# bert.encoder.layer.8.attention.self.query.bias     0.0
# bert.encoder.layer.8.attention.self.key.weight     0.0
# bert.encoder.layer.8.attention.self.key.bias       0.0
# bert.encoder.layer.8.attention.self.value.weight   0.0
# bert.encoder.layer.8.attention.self.value.bias     0.0
# bert.encoder.layer.8.attention.output.dense.weight 0.0
# bert.encoder.layer.8.attention.output.dense.bias   0.0
# bert.encoder.layer.8.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.8.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.8.intermediate.dense.weight     0.0
# bert.encoder.layer.8.intermediate.dense.bias       0.0
# bert.encoder.layer.8.output.dense.weight           0.0
# bert.encoder.layer.8.output.dense.bias             0.0
# bert.encoder.layer.8.output.LayerNorm.weight       0.0
# bert.encoder.layer.8.output.LayerNorm.bias         0.0
# bert.encoder.layer.9.attention.self.query.weight   0.0
# bert.encoder.layer.9.attention.self.query.bias     0.0
# bert.encoder.layer.9.attention.self.key.weight     0.0
# bert.encoder.layer.9.attention.self.key.bias       0.0
# bert.encoder.layer.9.attention.self.value.weight   0.0
# bert.encoder.layer.9.attention.self.value.bias     0.0
# bert.encoder.layer.9.attention.output.dense.weight 0.0
# bert.encoder.layer.9.attention.output.dense.bias   0.0
# bert.encoder.layer.9.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.9.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.9.intermediate.dense.weight     0.0
# bert.encoder.layer.9.intermediate.dense.bias       0.0
# bert.encoder.layer.9.output.dense.weight           0.0
# bert.encoder.layer.9.output.dense.bias             0.0
# bert.encoder.layer.9.output.LayerNorm.weight       0.0
# bert.encoder.layer.9.output.LayerNorm.bias         0.0
# bert.encoder.layer.10.attention.self.query.weight  0.0
# bert.encoder.layer.10.attention.self.query.bias    0.0
# bert.encoder.layer.10.attention.self.key.weight    0.0
# bert.encoder.layer.10.attention.self.key.bias      0.0
# bert.encoder.layer.10.attention.self.value.weight  0.0
# bert.encoder.layer.10.attention.self.value.bias    0.0
# bert.encoder.layer.10.attention.output.dense.weight 0.0
# bert.encoder.layer.10.attention.output.dense.bias  0.0
# bert.encoder.layer.10.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.10.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.10.intermediate.dense.weight    0.0
# bert.encoder.layer.10.intermediate.dense.bias      0.0
# bert.encoder.layer.10.output.dense.weight          0.0
# bert.encoder.layer.10.output.dense.bias            0.0
# bert.encoder.layer.10.output.LayerNorm.weight      0.0
# bert.encoder.layer.10.output.LayerNorm.bias        0.0
# bert.encoder.layer.11.attention.self.query.weight  0.0
# bert.encoder.layer.11.attention.self.query.bias    0.0
# bert.encoder.layer.11.attention.self.key.weight    0.0
# bert.encoder.layer.11.attention.self.key.bias      0.0
# bert.encoder.layer.11.attention.self.value.weight  0.0
# bert.encoder.layer.11.attention.self.value.bias    0.0
# bert.encoder.layer.11.attention.output.dense.weight 0.0
# bert.encoder.layer.11.attention.output.dense.bias  0.0
# bert.encoder.layer.11.attention.output.LayerNorm.weight 0.0
# bert.encoder.layer.11.attention.output.LayerNorm.bias 0.0
# bert.encoder.layer.11.intermediate.dense.weight    0.0
# bert.encoder.layer.11.intermediate.dense.bias      0.0
# bert.encoder.layer.11.output.dense.weight          0.0
# bert.encoder.layer.11.output.dense.bias            0.0
# bert.encoder.layer.11.output.LayerNorm.weight      0.0
# bert.encoder.layer.11.output.LayerNorm.bias        0.0
# bert.pooler.dense.weight                           0.0
# bert.pooler.dense.bias                             0.0
# classifier.weight                                  0.0
# classifier.bias                                    0.0
# ==================================================
# eval_loss                      1.4850542313035797
# eval_acc                       0.8308823529411765
# eval_f1                        0.8812392426850257
# eval_acc_and_f1                0.8560607978131012
# epoch                          10.0
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=10.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Evaluation', max=51.0, style=ProgressStyle(description_wi…
# 3 ================================================== sparsity 16.25999999999999
# bert.embeddings.word_embeddings.weight             0.16
# bert.embeddings.position_embeddings.weight         0.16
# bert.embeddings.token_type_embeddings.weight       0.16
# bert.embeddings.LayerNorm.weight                   0.16
# bert.embeddings.LayerNorm.bias                     0.16
# bert.encoder.layer.0.attention.self.query.weight   0.16
# bert.encoder.layer.0.attention.self.query.bias     0.16
# bert.encoder.layer.0.attention.self.key.weight     0.16
# bert.encoder.layer.0.attention.self.key.bias       0.16
# bert.encoder.layer.0.attention.self.value.weight   0.16
# bert.encoder.layer.0.attention.self.value.bias     0.16
# bert.encoder.layer.0.attention.output.dense.weight 0.16
# bert.encoder.layer.0.attention.output.dense.bias   0.16
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.0.intermediate.dense.weight     0.16
# bert.encoder.layer.0.intermediate.dense.bias       0.16
# bert.encoder.layer.0.output.dense.weight           0.16
# bert.encoder.layer.0.output.dense.bias             0.16
# bert.encoder.layer.0.output.LayerNorm.weight       0.16
# bert.encoder.layer.0.output.LayerNorm.bias         0.16
# bert.encoder.layer.1.attention.self.query.weight   0.16
# bert.encoder.layer.1.attention.self.query.bias     0.16
# bert.encoder.layer.1.attention.self.key.weight     0.16
# bert.encoder.layer.1.attention.self.key.bias       0.16
# bert.encoder.layer.1.attention.self.value.weight   0.16
# bert.encoder.layer.1.attention.self.value.bias     0.16
# bert.encoder.layer.1.attention.output.dense.weight 0.16
# bert.encoder.layer.1.attention.output.dense.bias   0.16
# bert.encoder.layer.1.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.1.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.1.intermediate.dense.weight     0.16
# bert.encoder.layer.1.intermediate.dense.bias       0.16
# bert.encoder.layer.1.output.dense.weight           0.16
# bert.encoder.layer.1.output.dense.bias             0.16
# bert.encoder.layer.1.output.LayerNorm.weight       0.16
# bert.encoder.layer.1.output.LayerNorm.bias         0.16
# bert.encoder.layer.2.attention.self.query.weight   0.16
# bert.encoder.layer.2.attention.self.query.bias     0.16
# bert.encoder.layer.2.attention.self.key.weight     0.16
# bert.encoder.layer.2.attention.self.key.bias       0.16
# bert.encoder.layer.2.attention.self.value.weight   0.16
# bert.encoder.layer.2.attention.self.value.bias     0.16
# bert.encoder.layer.2.attention.output.dense.weight 0.16
# bert.encoder.layer.2.attention.output.dense.bias   0.16
# bert.encoder.layer.2.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.2.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.2.intermediate.dense.weight     0.16
# bert.encoder.layer.2.intermediate.dense.bias       0.16
# bert.encoder.layer.2.output.dense.weight           0.16
# bert.encoder.layer.2.output.dense.bias             0.16
# bert.encoder.layer.2.output.LayerNorm.weight       0.16
# bert.encoder.layer.2.output.LayerNorm.bias         0.16
# bert.encoder.layer.3.attention.self.query.weight   0.16
# bert.encoder.layer.3.attention.self.query.bias     0.16
# bert.encoder.layer.3.attention.self.key.weight     0.16
# bert.encoder.layer.3.attention.self.key.bias       0.16
# bert.encoder.layer.3.attention.self.value.weight   0.16
# bert.encoder.layer.3.attention.self.value.bias     0.16
# bert.encoder.layer.3.attention.output.dense.weight 0.16
# bert.encoder.layer.3.attention.output.dense.bias   0.16
# bert.encoder.layer.3.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.3.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.3.intermediate.dense.weight     0.16
# bert.encoder.layer.3.intermediate.dense.bias       0.16
# bert.encoder.layer.3.output.dense.weight           0.16
# bert.encoder.layer.3.output.dense.bias             0.16
# bert.encoder.layer.3.output.LayerNorm.weight       0.16
# bert.encoder.layer.3.output.LayerNorm.bias         0.16
# bert.encoder.layer.4.attention.self.query.weight   0.16
# bert.encoder.layer.4.attention.self.query.bias     0.16
# bert.encoder.layer.4.attention.self.key.weight     0.16
# bert.encoder.layer.4.attention.self.key.bias       0.16
# bert.encoder.layer.4.attention.self.value.weight   0.16
# bert.encoder.layer.4.attention.self.value.bias     0.16
# bert.encoder.layer.4.attention.output.dense.weight 0.16
# bert.encoder.layer.4.attention.output.dense.bias   0.16
# bert.encoder.layer.4.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.4.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.4.intermediate.dense.weight     0.16
# bert.encoder.layer.4.intermediate.dense.bias       0.16
# bert.encoder.layer.4.output.dense.weight           0.16
# bert.encoder.layer.4.output.dense.bias             0.16
# bert.encoder.layer.4.output.LayerNorm.weight       0.16
# bert.encoder.layer.4.output.LayerNorm.bias         0.16
# bert.encoder.layer.5.attention.self.query.weight   0.16
# bert.encoder.layer.5.attention.self.query.bias     0.16
# bert.encoder.layer.5.attention.self.key.weight     0.16
# bert.encoder.layer.5.attention.self.key.bias       0.16
# bert.encoder.layer.5.attention.self.value.weight   0.16
# bert.encoder.layer.5.attention.self.value.bias     0.16
# bert.encoder.layer.5.attention.output.dense.weight 0.16
# bert.encoder.layer.5.attention.output.dense.bias   0.16
# bert.encoder.layer.5.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.5.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.5.intermediate.dense.weight     0.16
# bert.encoder.layer.5.intermediate.dense.bias       0.16
# bert.encoder.layer.5.output.dense.weight           0.16
# bert.encoder.layer.5.output.dense.bias             0.16
# bert.encoder.layer.5.output.LayerNorm.weight       0.16
# bert.encoder.layer.5.output.LayerNorm.bias         0.16
# bert.encoder.layer.6.attention.self.query.weight   0.16
# bert.encoder.layer.6.attention.self.query.bias     0.16
# bert.encoder.layer.6.attention.self.key.weight     0.16
# bert.encoder.layer.6.attention.self.key.bias       0.16
# bert.encoder.layer.6.attention.self.value.weight   0.16
# bert.encoder.layer.6.attention.self.value.bias     0.16
# bert.encoder.layer.6.attention.output.dense.weight 0.16
# bert.encoder.layer.6.attention.output.dense.bias   0.16
# bert.encoder.layer.6.attention.output.LayerNorm.weight 0.16
# bert.encoder.layer.6.attention.output.LayerNorm.bias 0.16
# bert.encoder.layer.6.intermediate.dense.weight     0.16
# bert.encoder.layer.6.intermediate.dense.bias       0.16
# bert.encoder.layer.6.output.dense.weight           0.16
# bert.encoder.layer.6.output.dense.bias             0.16
# bert.encoder.layer.6.output.LayerNorm.weight       0.16
# bert.encoder.layer.6.output.LayerNorm.bias         0.16
# bert.encoder.layer.7.attention.self.query.weight   0.16
# ...
# bert.encoder.layer.9.attention.self.value.bias     0.56
# bert.encoder.layer.9.attention.output.dense.weight 0.56
# bert.encoder.layer.9.attention.output.dense.bias   0.56
# bert.encoder.layer.9.attention.output.LayerNorm.weight 0.56
# bert.encoder.layer.9.attention.output.LayerNorm.bias 0.56
# bert.encoder.layer.9.intermediate.dense.weight     0.56
# bert.encoder.layer.9.intermediate.dense.bias       0.56
# bert.encoder.layer.9.output.dense.weight           0.56
# bert.encoder.layer.9.output.dense.bias             0.56
# bert.encoder.layer.9.output.LayerNorm.weight       0.56
# bert.encoder.layer.9.output.LayerNorm.bias         0.56
# bert.encoder.layer.10.attention.self.query.weight  0.56
# bert.encoder.layer.10.attention.self.query.bias    0.56
# bert.encoder.layer.10.attention.self.key.weight    0.56
# bert.encoder.layer.10.attention.self.key.bias      0.56
# bert.encoder.layer.10.attention.self.value.weight  0.56
# bert.encoder.layer.10.attention.self.value.bias    0.56
# bert.encoder.layer.10.attention.output.dense.weight 0.56
# bert.encoder.layer.10.attention.output.dense.bias  0.56
# bert.encoder.layer.10.attention.output.LayerNorm.weight 0.56
# bert.encoder.layer.10.attention.output.LayerNorm.bias 0.56
# bert.encoder.layer.10.intermediate.dense.weight    0.56
# bert.encoder.layer.10.intermediate.dense.bias      0.56
# bert.encoder.layer.10.output.dense.weight          0.56
# bert.encoder.layer.10.output.dense.bias            0.56
# bert.encoder.layer.10.output.LayerNorm.weight      0.56
# bert.encoder.layer.10.output.LayerNorm.bias        0.56
# bert.encoder.layer.11.attention.self.query.weight  0.56
# bert.encoder.layer.11.attention.self.query.bias    0.56
# bert.encoder.layer.11.attention.self.key.weight    0.56
# bert.encoder.layer.11.attention.self.key.bias      0.56
# bert.encoder.layer.11.attention.self.value.weight  0.56
# bert.encoder.layer.11.attention.self.value.bias    0.56
# bert.encoder.layer.11.attention.output.dense.weight 0.56
# bert.encoder.layer.11.attention.output.dense.bias  0.56
# bert.encoder.layer.11.attention.output.LayerNorm.weight 0.56
# bert.encoder.layer.11.attention.output.LayerNorm.bias 0.56
# bert.encoder.layer.11.intermediate.dense.weight    0.56
# bert.encoder.layer.11.intermediate.dense.bias      0.56
# bert.encoder.layer.11.output.dense.weight          0.56
# bert.encoder.layer.11.output.dense.bias            0.56
# bert.encoder.layer.11.output.LayerNorm.weight      0.56
# bert.encoder.layer.11.output.LayerNorm.bias        0.56
# bert.pooler.dense.weight                           0.0
# bert.pooler.dense.bias                             0.0
# classifier.weight                                  0.0
# classifier.bias                                    0.0
# ==================================================
# eval_loss                      2.8710555533568063
# eval_acc                       0.7009803921568627
# eval_f1                        0.7986798679867988
# eval_acc_and_f1                0.7498301300718307
# epoch                          10.0
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=10.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=115.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Evaluation', max=51.0, style=ProgressStyle(description_wi…
# 9 ================================================== sparsity 58.38
# bert.embeddings.word_embeddings.weight             0.58
# bert.embeddings.position_embeddings.weight         0.58
# bert.embeddings.token_type_embeddings.weight       0.58
# bert.embeddings.LayerNorm.weight                   0.58
# bert.embeddings.LayerNorm.bias                     0.58
# bert.encoder.layer.0.attention.self.query.weight   0.58
# bert.encoder.layer.0.attention.self.query.bias     0.58
# bert.encoder.layer.0.attention.self.key.weight     0.58
# bert.encoder.layer.0.attention.self.key.bias       0.58
# bert.encoder.layer.0.attention.self.value.weight   0.58
# bert.encoder.layer.0.attention.self.value.bias     0.58
# bert.encoder.layer.0.attention.output.dense.weight 0.58
# bert.encoder.layer.0.attention.output.dense.bias   0.58
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.0.intermediate.dense.weight     0.58
# bert.encoder.layer.0.intermediate.dense.bias       0.58
# bert.encoder.layer.0.output.dense.weight           0.58
# bert.encoder.layer.0.output.dense.bias             0.58
# bert.encoder.layer.0.output.LayerNorm.weight       0.58
# bert.encoder.layer.0.output.LayerNorm.bias         0.58
# bert.encoder.layer.1.attention.self.query.weight   0.58
# bert.encoder.layer.1.attention.self.query.bias     0.58
# bert.encoder.layer.1.attention.self.key.weight     0.58
# bert.encoder.layer.1.attention.self.key.bias       0.58
# bert.encoder.layer.1.attention.self.value.weight   0.58
# bert.encoder.layer.1.attention.self.value.bias     0.58
# bert.encoder.layer.1.attention.output.dense.weight 0.58
# bert.encoder.layer.1.attention.output.dense.bias   0.58
# bert.encoder.layer.1.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.1.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.1.intermediate.dense.weight     0.58
# bert.encoder.layer.1.intermediate.dense.bias       0.58
# bert.encoder.layer.1.output.dense.weight           0.58
# bert.encoder.layer.1.output.dense.bias             0.58
# bert.encoder.layer.1.output.LayerNorm.weight       0.58
# bert.encoder.layer.1.output.LayerNorm.bias         0.58
# bert.encoder.layer.2.attention.self.query.weight   0.58
# bert.encoder.layer.2.attention.self.query.bias     0.58
# bert.encoder.layer.2.attention.self.key.weight     0.58
# bert.encoder.layer.2.attention.self.key.bias       0.58
# bert.encoder.layer.2.attention.self.value.weight   0.58
# bert.encoder.layer.2.attention.self.value.bias     0.58
# bert.encoder.layer.2.attention.output.dense.weight 0.58
# bert.encoder.layer.2.attention.output.dense.bias   0.58
# bert.encoder.layer.2.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.2.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.2.intermediate.dense.weight     0.58
# bert.encoder.layer.2.intermediate.dense.bias       0.58
# bert.encoder.layer.2.output.dense.weight           0.58
# bert.encoder.layer.2.output.dense.bias             0.58
# bert.encoder.layer.2.output.LayerNorm.weight       0.58
# bert.encoder.layer.2.output.LayerNorm.bias         0.58
# bert.encoder.layer.3.attention.self.query.weight   0.58
# bert.encoder.layer.3.attention.self.query.bias     0.58
# bert.encoder.layer.3.attention.self.key.weight     0.58
# bert.encoder.layer.3.attention.self.key.bias       0.58
# bert.encoder.layer.3.attention.self.value.weight   0.58
# bert.encoder.layer.3.attention.self.value.bias     0.58
# bert.encoder.layer.3.attention.output.dense.weight 0.58
# bert.encoder.layer.3.attention.output.dense.bias   0.58
# bert.encoder.layer.3.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.3.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.3.intermediate.dense.weight     0.58
# bert.encoder.layer.3.intermediate.dense.bias       0.58
# bert.encoder.layer.3.output.dense.weight           0.58
# bert.encoder.layer.3.output.dense.bias             0.58
# bert.encoder.layer.3.output.LayerNorm.weight       0.58
# bert.encoder.layer.3.output.LayerNorm.bias         0.58
# bert.encoder.layer.4.attention.self.query.weight   0.58
# bert.encoder.layer.4.attention.self.query.bias     0.58
# bert.encoder.layer.4.attention.self.key.weight     0.58
# bert.encoder.layer.4.attention.self.key.bias       0.58
# bert.encoder.layer.4.attention.self.value.weight   0.58
# bert.encoder.layer.4.attention.self.value.bias     0.58
# bert.encoder.layer.4.attention.output.dense.weight 0.58
# bert.encoder.layer.4.attention.output.dense.bias   0.58
# bert.encoder.layer.4.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.4.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.4.intermediate.dense.weight     0.58
# bert.encoder.layer.4.intermediate.dense.bias       0.58
# bert.encoder.layer.4.output.dense.weight           0.58
# bert.encoder.layer.4.output.dense.bias             0.58
# bert.encoder.layer.4.output.LayerNorm.weight       0.58
# bert.encoder.layer.4.output.LayerNorm.bias         0.58
# bert.encoder.layer.5.attention.self.query.weight   0.58
# bert.encoder.layer.5.attention.self.query.bias     0.58
# bert.encoder.layer.5.attention.self.key.weight     0.58
# bert.encoder.layer.5.attention.self.key.bias       0.58
# bert.encoder.layer.5.attention.self.value.weight   0.58
# bert.encoder.layer.5.attention.self.value.bias     0.58
# bert.encoder.layer.5.attention.output.dense.weight 0.58
# bert.encoder.layer.5.attention.output.dense.bias   0.58
# bert.encoder.layer.5.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.5.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.5.intermediate.dense.weight     0.58
# bert.encoder.layer.5.intermediate.dense.bias       0.58
# bert.encoder.layer.5.output.dense.weight           0.58
# bert.encoder.layer.5.output.dense.bias             0.58
# bert.encoder.layer.5.output.LayerNorm.weight       0.58
# bert.encoder.layer.5.output.LayerNorm.bias         0.58
# bert.encoder.layer.6.attention.self.query.weight   0.58
# bert.encoder.layer.6.attention.self.query.bias     0.58
# bert.encoder.layer.6.attention.self.key.weight     0.58
# bert.encoder.layer.6.attention.self.key.bias       0.58
# bert.encoder.layer.6.attention.self.value.weight   0.58
# bert.encoder.layer.6.attention.self.value.bias     0.58
# bert.encoder.layer.6.attention.output.dense.weight 0.58
# bert.encoder.layer.6.attention.output.dense.bias   0.58
# bert.encoder.layer.6.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.6.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.6.intermediate.dense.weight     0.58
# bert.encoder.layer.6.intermediate.dense.bias       0.58
# bert.encoder.layer.6.output.dense.weight           0.58
# bert.encoder.layer.6.output.dense.bias             0.58
# bert.encoder.layer.6.output.LayerNorm.weight       0.58
# bert.encoder.layer.6.output.LayerNorm.bias         0.58
# bert.encoder.layer.7.attention.self.query.weight   0.58
# bert.encoder.layer.7.attention.self.query.bias     0.58
# bert.encoder.layer.7.attention.self.key.weight     0.58
# bert.encoder.layer.7.attention.self.key.bias       0.58
# bert.encoder.layer.7.attention.self.value.weight   0.58
# bert.encoder.layer.7.attention.self.value.bias     0.58
# bert.encoder.layer.7.attention.output.dense.weight 0.58
# bert.encoder.layer.7.attention.output.dense.bias   0.58
# bert.encoder.layer.7.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.7.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.7.intermediate.dense.weight     0.58
# bert.encoder.layer.7.intermediate.dense.bias       0.58
# bert.encoder.layer.7.output.dense.weight           0.58
# bert.encoder.layer.7.output.dense.bias             0.58
# bert.encoder.layer.7.output.LayerNorm.weight       0.58
# bert.encoder.layer.7.output.LayerNorm.bias         0.58
# bert.encoder.layer.8.attention.self.query.weight   0.58
# bert.encoder.layer.8.attention.self.query.bias     0.58
# bert.encoder.layer.8.attention.self.key.weight     0.58
# bert.encoder.layer.8.attention.self.key.bias       0.58
# bert.encoder.layer.8.attention.self.value.weight   0.58
# bert.encoder.layer.8.attention.self.value.bias     0.58
# bert.encoder.layer.8.attention.output.dense.weight 0.58
# bert.encoder.layer.8.attention.output.dense.bias   0.58
# bert.encoder.layer.8.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.8.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.8.intermediate.dense.weight     0.58
# bert.encoder.layer.8.intermediate.dense.bias       0.58
# bert.encoder.layer.8.output.dense.weight           0.58
# bert.encoder.layer.8.output.dense.bias             0.58
# bert.encoder.layer.8.output.LayerNorm.weight       0.58
# bert.encoder.layer.8.output.LayerNorm.bias         0.58
# bert.encoder.layer.9.attention.self.query.weight   0.58
# bert.encoder.layer.9.attention.self.query.bias     0.58
# bert.encoder.layer.9.attention.self.key.weight     0.58
# bert.encoder.layer.9.attention.self.key.bias       0.58
# bert.encoder.layer.9.attention.self.value.weight   0.58
# bert.encoder.layer.9.attention.self.value.bias     0.58
# bert.encoder.layer.9.attention.output.dense.weight 0.58
# bert.encoder.layer.9.attention.output.dense.bias   0.58
# bert.encoder.layer.9.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.9.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.9.intermediate.dense.weight     0.58
# bert.encoder.layer.9.intermediate.dense.bias       0.58
# bert.encoder.layer.9.output.dense.weight           0.58
# bert.encoder.layer.9.output.dense.bias             0.58
# bert.encoder.layer.9.output.LayerNorm.weight       0.58
# bert.encoder.layer.9.output.LayerNorm.bias         0.58
# bert.encoder.layer.10.attention.self.query.weight  0.58
# bert.encoder.layer.10.attention.self.query.bias    0.58
# bert.encoder.layer.10.attention.self.key.weight    0.58
# bert.encoder.layer.10.attention.self.key.bias      0.58
# bert.encoder.layer.10.attention.self.value.weight  0.58
# bert.encoder.layer.10.attention.self.value.bias    0.58
# bert.encoder.layer.10.attention.output.dense.weight 0.58
# bert.encoder.layer.10.attention.output.dense.bias  0.58
# bert.encoder.layer.10.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.10.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.10.intermediate.dense.weight    0.58
# bert.encoder.layer.10.intermediate.dense.bias      0.58
# bert.encoder.layer.10.output.dense.weight          0.58
# bert.encoder.layer.10.output.dense.bias            0.58
# bert.encoder.layer.10.output.LayerNorm.weight      0.58
# bert.encoder.layer.10.output.LayerNorm.bias        0.58
# bert.encoder.layer.11.attention.self.query.weight  0.58
# bert.encoder.layer.11.attention.self.query.bias    0.58
# bert.encoder.layer.11.attention.self.key.weight    0.58
# bert.encoder.layer.11.attention.self.key.bias      0.58
# bert.encoder.layer.11.attention.self.value.weight  0.58
# bert.encoder.layer.11.attention.self.value.bias    0.58
# bert.encoder.layer.11.attention.output.dense.weight 0.58
# bert.encoder.layer.11.attention.output.dense.bias  0.58
# bert.encoder.layer.11.attention.output.LayerNorm.weight 0.58
# bert.encoder.layer.11.attention.output.LayerNorm.bias 0.58
# bert.encoder.layer.11.intermediate.dense.weight    0.58
# bert.encoder.layer.11.intermediate.dense.bias      0.58
# bert.encoder.layer.11.output.dense.weight          0.58
# bert.encoder.layer.11.output.dense.bias            0.58
# bert.encoder.layer.11.output.LayerNorm.weight      0.58
# bert.encoder.layer.11.output.LayerNorm.bias        0.58
# bert.pooler.dense.weight                           0.0
# bert.pooler.dense.bias                             0.0
# classifier.weight                                  0.0
# classifier.bias                                    0.0
# ==================================================
# eval_loss                      3.0392298634145773
# eval_acc                       0.7132352941176471
# eval_f1                        0.8053244592346089
# eval_acc_and_f1                0.759279876676128
# epoch                          10.0
