# %% [markdown]
# ## Evaluation & Prediction
# with this notebook you can load your pre_trained model, analyze it and create prediction file over the test set.
#
# ### Inputs
#  * hyper params file
#  * path to pre trained model weights(.pt)

# %% [markdown]
# ### Imports and Enviroment Params

# %%
from analyze_and_predict import *

PARAMS = "hyper_params.json"
MODEL = "models/2020-July-20 20-06-46/pt_state_dict/model_state_dict_5.pt"

model, trainer, train_dataset, eval_dataset, test_dataset = load_enviroment(MODEL, params_file=PARAMS)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# ### analyze

# %%
analayze_and_predict(model, trainer, train_dataset, eval_dataset)
# Out:
# ...
# ========== Sparsity ==========
# bert.embeddings.word_embeddings.weight             0.39
# bert.embeddings.position_embeddings.weight         0.39
# bert.embeddings.token_type_embeddings.weight       0.39
# bert.embeddings.LayerNorm.weight                   0.39
# bert.embeddings.LayerNorm.bias                     0.39
# bert.encoder.layer.0.attention.self.query.weight   0.39
# bert.encoder.layer.0.attention.self.query.bias     0.39
# bert.encoder.layer.0.attention.self.key.weight     0.39
# bert.encoder.layer.0.attention.self.key.bias       0.39
# bert.encoder.layer.0.attention.self.value.weight   0.39
# bert.encoder.layer.0.attention.self.value.bias     0.39
# bert.encoder.layer.0.attention.output.dense.weight 0.39
# bert.encoder.layer.0.attention.output.dense.bias   0.39
# bert.encoder.layer.0.attention.output.LayerNorm.weight 0.39
# bert.encoder.layer.0.attention.output.LayerNorm.bias 0.39
# bert.encoder.layer.0.intermediate.dense.weight     0.39
# ...

# %%
TESTT_RESULTS_FILE = "test.res"
export_predictions(trainer, dataset, TESTT_RESULTS_FILE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9a8bc35e43fc> in <module>
#       1 TESTT_RESULTS_FILE = "test.res"
# ----> 2 export_predictions(trainer, dataset, TESTT_RESULTS_FILE)
#
# NameError: name 'dataset' is not defined
